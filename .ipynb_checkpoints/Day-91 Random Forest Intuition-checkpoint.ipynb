# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
import random

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.210560 -3.133195  1.042555 -2.921725  0.609947       0
# 1 -0.407701  1.658483  0.935543  2.588702  0.348103       0
# 2  1.444884  0.652950  1.217748  0.997525  2.554657       0
# 3  0.687154  0.401620 -1.009523 -1.730344 -0.062311       1
# 4  1.448560  1.294580  0.414422  1.511910  1.125025       0

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
# function for feature sampling
def sample_features(df,percent):
  cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
  new_df = df[cols]
  new_df['target'] = df['target']
  return new_df

# %%
# function for combined sampling

def combined_sampling(df,row_percent,col_percent):
  new_df = sample_rows(df,row_percent)
  return sample_features(new_df,col_percent)

# %%
df1 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_14268\3275485051.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_14268\3275485051.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_14268\3275485051.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col4', 'col1', 'target'], dtype='object')
# Index(['col1', 'col5', 'target'], dtype='object')
# Index(['col5', 'col2', 'target'], dtype='object')

# %%
df3
# Out:
#         col5      col2  target
# 95  0.828453  1.093857       1
# 0   0.609947 -3.133195       0
# 73  1.932417 -0.887844       0
# 21  1.687846  2.283175       1
# 6   0.505785 -2.132685       0
# 96 -1.379613 -1.988254       0
# 34  1.108974 -1.259713       0
# 91  2.536391 -1.292762       0
# 82  0.459027 -2.108980       0
# 34  1.108974 -1.259713       0
# 53  3.296210  2.473039       1
# 72  1.657795 -1.052866       0
# 3  -0.062311  0.401620       1
# 95  0.828453  1.093857       1
# 23  1.122155  1.495910       1
# 95  0.828453  1.093857       1
# 4   1.125025  1.294580       0
# 39  0.011252  0.395146       0
# 38 -1.345380 -0.212949       1
# 14 -0.039363  0.718458       1
# 50  1.637782 -0.213974       0
# 32  0.995676  1.318671       1
# 1   0.348103  1.658483       0
# 58  1.339886 -3.445000       0
# 33  1.525545  0.831870       1
# 64  0.164463  0.348353       1
# 40  0.369508  0.416625       1
# 28  1.301629  1.686103       1
# 67  1.111527  0.153950       0
# 62 -1.785051 -0.980270       1
# 33  1.525545  0.831870       1
# 23  1.122155  1.495910       1
# 22  1.243990  1.248253       1
# 78  1.085087  1.250033       1
# 71 -1.692969 -0.637368       1
# 94  0.550769 -0.238174       0
# 5  -0.244574 -2.027989       0
# 1   0.348103  1.658483       0
# 4   1.125025  1.294580       0
# 53  3.296210  2.473039       1
# 15  2.741389 -0.009957       0
# 0   0.609947 -3.133195       0
# 38 -1.345380 -0.212949       1
# 60  0.532462 -0.955990       0
# 1   0.348103  1.658483       0
# 98  0.646813 -1.011046       0
# 73  1.932417 -0.887844       0
# 23  1.122155  1.495910       1
# 18  0.703884  0.582791       1
# 72  1.657795 -1.052866       0

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5833333333333334, 0.9375, 'x[1] <= 3.52\ngini = 0.493\nsamples = 50\nvalue = [28.0, 22.0]'),
#  Text(0.5357142857142857, 0.8125, 'x[1] <= 1.206\ngini = 0.482\nsamples = 47\nvalue = [28, 19]'),
#  Text(0.30952380952380953, 0.6875, 'x[0] <= -1.505\ngini = 0.486\nsamples = 24\nvalue = [10, 14]'),
#  Text(0.19047619047619047, 0.5625, 'x[1] <= -1.292\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.09523809523809523, 0.4375, 'x[0] <= -1.695\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.047619047619047616, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.14285714285714285, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2857142857142857, 0.4375, 'x[0] <= -2.942\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.23809523809523808, 0.3125, 'x[0] <= -3.387\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19047619047619047, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2857142857142857, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.42857142857142855, 0.5625, 'x[0] <= -0.528\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.38095238095238093, 0.4375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.47619047619047616, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7619047619047619, 0.6875, 'x[1] <= 2.525\ngini = 0.34\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.6190476190476191, 0.5625, 'x[1] <= 1.528\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.5714285714285714, 0.4375, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6666666666666666, 0.4375, 'x[1] <= 1.576\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.6190476190476191, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7142857142857143, 0.3125, 'x[1] <= 2.307\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.6666666666666666, 0.1875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7619047619047619, 0.1875, 'x[1] <= 2.397\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7142857142857143, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8095238095238095, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9047619047619048, 0.5625, 'x[1] <= 3.272\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.8571428571428571, 0.4375, 'x[0] <= -1.141\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8095238095238095, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9047619047619048, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9523809523809523, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6309523809523809, 0.8125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5789473684210527, 0.9375, 'x[0] <= 3.129\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.5263157894736842, 0.8125, 'x[0] <= 1.278\ngini = 0.488\nsamples = 45\nvalue = [26.0, 19.0]'),
#  Text(0.2631578947368421, 0.6875, 'x[1] <= 0.807\ngini = 0.454\nsamples = 23\nvalue = [8, 15]'),
#  Text(0.15789473684210525, 0.5625, 'x[1] <= 0.457\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.10526315789473684, 0.4375, 'x[1] <= -1.362\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.05263157894736842, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15789473684210525, 0.3125, 'x[0] <= -0.295\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.10526315789473684, 0.1875, 'x[1] <= -0.576\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.05263157894736842, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15789473684210525, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21052631578947367, 0.4375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3684210526315789, 0.5625, 'x[0] <= 0.353\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.3157894736842105, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.42105263157894735, 0.4375, 'x[0] <= 0.503\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3684210526315789, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.47368421052631576, 0.3125, 'x[0] <= 1.173\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.42105263157894735, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5263157894736842, 0.1875, 'x[1] <= 1.022\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.47368421052631576, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5789473684210527, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7894736842105263, 0.6875, 'x[0] <= 2.525\ngini = 0.298\nsamples = 22\nvalue = [18, 4]'),
#  Text(0.6842105263157895, 0.5625, 'x[1] <= -0.132\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.631578947368421, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7368421052631579, 0.4375, 'x[0] <= 1.56\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.6842105263157895, 0.3125, 'x[0] <= 1.528\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.631578947368421, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7368421052631579, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7894736842105263, 0.3125, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.8947368421052632, 0.5625, 'x[1] <= 3.594\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8421052631578947, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9473684210526315, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.631578947368421, 0.8125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.3088235294117647, 0.9166666666666666, 'x[1] <= -0.213\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.11764705882352941, 0.75, 'x[0] <= -1.536\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.058823529411764705, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17647058823529413, 0.5833333333333334, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.5, 0.75, 'x[1] <= 0.398\ngini = 0.391\nsamples = 30\nvalue = [8, 22]'),
#  Text(0.29411764705882354, 0.5833333333333334, 'x[1] <= -0.111\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.23529411764705882, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35294117647058826, 0.4166666666666667, 'x[1] <= 0.251\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.29411764705882354, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4117647058823529, 0.25, 'x[1] <= 0.372\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.35294117647058826, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47058823529411764, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7058823529411765, 0.5833333333333334, 'x[0] <= 0.359\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.5882352941176471, 0.4166666666666667, 'x[1] <= 1.188\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.5294117647058824, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6470588235294118, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8235294117647058, 0.4166666666666667, 'x[0] <= 1.124\ngini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(0.7647058823529411, 0.25, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.8823529411764706, 0.25, 'x[0] <= 1.185\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.8235294117647058, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9411764705882353, 0.08333333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]')]

# %%
clf1.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\A\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\A\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\A\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
